# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# !pip install pandas numpy
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.5.0-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    ------------ --------------------------- 3.1/9.9 MB 12.1 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.9 MB 12.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 12.8 MB/s  0:00:00
# Downloading numpy-2.5.0-cp314-cp314-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/12.6 MB 14.6 MB/s eta 0:00:01
#    ------------------ --------------------- 5.8/12.6 MB 14.3 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 14.5 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 14.2 MB/s  0:00:00
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: tzdata, numpy, pandas
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed numpy-2.5.0 pandas-3.0.3 tzdata-2026.2

# %%
# !pip install matplotlib seaborn scipy scikit-learn
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.11.0-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scipy
#   Using cached scipy-1.18.0-cp314-cp314-win_amd64.whl.metadata (61 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in .\.venv\Lib\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in .\.venv\Lib\site-packages (from seaborn) (3.0.3)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp314-cp314-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.5 MB 7.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.5 MB 15.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 18.2 MB/s  0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading scipy-1.18.0-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ----- ---------------------------------- 4.7/37.3 MB 23.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.2/37.3 MB 24.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.7/37.3 MB 25.0 MB/s eta 0:00:01
#    --------------------- ------------------ 20.2/37.3 MB 24.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 26.2/37.3 MB 25.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 31.7/37.3 MB 25.9 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 26.1 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 24.9 MB/s  0:00:01
# Downloading scikit_learn-1.9.0-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    -------------------------- ------------- 5.5/8.3 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 24.8 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 16.1 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ----------------------------- ---------- 5.2/7.2 MB 28.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 19.2 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, pyparsing, pillow, narwhals, kiwisolver, joblib, fonttools, cycler, contourpy, scikit-learn, matplotlib, seaborn
#
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    --- ------------------------------------  1/13 [scipy]
#    ------ ---------------------------------  2/13 [pyparsing]
#    ------ ---------------------------------  2/13 [pyparsing]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------ ---------------------------  4/13 [narwhals]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------- ------------------  7/13 [fonttools]
#    --------------------------- ------------  9/13 [contourpy]
#    --------------------------- ------------  9/13 [contourpy]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [scikit-learn]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ---------------------------------------- 13/13 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 joblib-1.5.3 kiwisolver-1.5.0 matplotlib-3.11.0 narwhals-2.22.1 pillow-12.2.0 pyparsing-3.3.2 scikit-learn-1.9.0 scipy-1.18.0 seaborn-0.13.2 threadpoolctl-3.6.0

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\golan\DataScience

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2

# %%
# !pip install anthropic
# Out:
# Collecting anthropic
#   Downloading anthropic-0.115.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting anyio<5,>=3.5.0 (from anthropic)
#   Downloading anyio-4.14.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from anthropic)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Downloading jiter-0.16.0-cp314-cp314-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from anthropic)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting sniffio (from anthropic)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.14 in .\.venv\Lib\site-packages (from anthropic) (4.15.0)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->anthropic)
#   Downloading idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting certifi (from httpx<1,>=0.25.0->anthropic)
#   Downloading certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->anthropic)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->anthropic)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading pydantic_core-2.46.4-cp314-cp314-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading anthropic-0.115.1-py3-none-any.whl (957 kB)
#    ---------------------------------------- 0.0/957.0 kB ? eta -:--:--
#    ---------------------------------------- 957.0/957.0 kB 6.3 MB/s  0:00:00
# Downloading anyio-4.14.1-py3-none-any.whl (124 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.16.0-cp314-cp314-win_amd64.whl (198 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp314-cp314-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 15.6 MB/s  0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.18-py3-none-any.whl (65 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading certifi-2026.6.17-py3-none-any.whl (133 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-inspection, sniffio, pydantic-core, jiter, idna, h11, docstring-parser, distro, certifi, annotated-types, pydantic, httpcore, anyio, httpx, anthropic
#
#    ----- ----------------------------------  2/15 [pydantic-core]
#    ---------- -----------------------------  4/15 [idna]
#    ------------- --------------------------  5/15 [h11]
#    ------------- --------------------------  5/15 [h11]
#    ------------------ ---------------------  7/15 [distro]
#    --------------------- ------------------  8/15 [certifi]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    -------------------------- ------------- 10/15 [pydantic]
#    ----------------------------- ---------- 11/15 [httpcore]
#    ----------------------------- ---------- 11/15 [httpcore]
#    ----------------------------- ---------- 11/15 [httpcore]
#    -------------------------------- ------- 12/15 [anyio]
#    -------------------------------- ------- 12/15 [anyio]
#    -------------------------------- ------- 12/15 [anyio]
#    -------------------------------- ------- 12/15 [anyio]
#    ---------------------------------- ----- 13/15 [httpx]
#    ---------------------------------- ----- 13/15 [httpx]
#    ---------------------------------- ----- 13/15 [httpx]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ------------------------------------- -- 14/15 [anthropic]
#    ---------------------------------------- 15/15 [anthropic]
#
# Successfully installed annotated-types-0.7.0 anthropic-0.115.1 anyio-4.14.1 certifi-2026.6.17 distro-1.9.0 docstring-parser-0.18.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.18 jiter-0.16.0 pydantic-2.13.4 pydantic-core-2.46.4 sniffio-1.3.1 typing-inspection-0.4.2

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.43.45-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<1.44.0,>=1.43.45 (from boto3)
#   Downloading botocore-1.43.45-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.20.0,>=0.19.0 (from boto3)
#   Downloading s3transfer-0.19.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in .\.venv\Lib\site-packages (from botocore<1.44.0,>=1.43.45->boto3) (2.9.0.post0)
# Collecting urllib3!=2.2.0,<3,>=1.25.4 (from botocore<1.44.0,>=1.43.45->boto3)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.45->boto3) (1.17.0)
# Downloading boto3-1.43.45-py3-none-any.whl (140 kB)
# Downloading botocore-1.43.45-py3-none-any.whl (15.4 MB)
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/15.4 MB 8.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/15.4 MB 15.5 MB/s eta 0:00:01
#    --------------------- ------------------ 8.4/15.4 MB 15.1 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.4 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 15.4/15.4 MB 16.0 MB/s  0:00:01
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.19.0-py3-none-any.whl (90 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [jmespath]
#    -------- ------------------------------- 1/5 [jmespath]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ---------------- ----------------------- 2/5 [botocore]
#    ------------------------ --------------- 3/5 [s3transfer]
#    ------------------------ --------------- 3/5 [s3transfer]
#    ------------------------ --------------- 3/5 [s3transfer]
#    ------------------------ --------------- 3/5 [s3transfer]
#    -------------------------------- ------- 4/5 [boto3]
#    -------------------------------- ------- 4/5 [boto3]
#    -------------------------------- ------- 4/5 [boto3]
#    -------------------------------- ------- 4/5 [boto3]
#    -------------------------------- ------- 4/5 [boto3]
#    -------------------------------- ------- 4/5 [boto3]
#    -------------------------------- ------- 4/5 [boto3]
#    ---------------------------------------- 5/5 [boto3]
#
# Successfully installed boto3-1.43.45 botocore-1.43.45 jmespath-1.1.0 s3transfer-0.19.0 urllib3-2.7.0

# %%
awscli==1.32.74
boto3==1.34.74
botocore==1.34.74
anthropic==0.21.3
pickleshare==0.7.5

# %%
# !pip install botocore
# Out:
# Requirement already satisfied: botocore in .\.venv\Lib\site-packages (1.43.45)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in .\.venv\Lib\site-packages (from botocore) (1.1.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in .\.venv\Lib\site-packages (from botocore) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in .\.venv\Lib\site-packages (from botocore) (2.7.0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.17.0)

# %%
# !pip install pickleshare
# Out:
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare
# Successfully installed pickleshare-0.7.5

# %%
# !pip install awscli
# Out:
# Collecting awscli
#   Downloading awscli-1.45.45-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: botocore==1.43.45 in .\.venv\Lib\site-packages (from awscli) (1.43.45)
# Collecting docutils<=0.19,>=0.18.1 (from awscli)
#   Downloading docutils-0.19-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in .\.venv\Lib\site-packages (from awscli) (0.19.0)
# Collecting PyYAML<6.1,>=3.10 (from awscli)
#   Downloading pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in .\.venv\Lib\site-packages (from awscli) (0.4.6)
# Collecting rsa<4.8,>=3.1.2 (from awscli)
#   Downloading rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in .\.venv\Lib\site-packages (from botocore==1.43.45->awscli) (1.1.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in .\.venv\Lib\site-packages (from botocore==1.43.45->awscli) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in .\.venv\Lib\site-packages (from botocore==1.43.45->awscli) (2.7.0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.43.45->awscli) (1.17.0)
# Collecting pyasn1>=0.1.3 (from rsa<4.8,>=3.1.2->awscli)
#   Downloading pyasn1-0.6.4-py3-none-any.whl.metadata (8.4 kB)
# Downloading awscli-1.45.45-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    -------------------- ------------------- 2.4/4.7 MB 9.6 MB/s eta 0:00:01
#    -------------------------------------- - 4.5/4.7 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 9.1 MB/s  0:00:00
# Downloading docutils-0.19-py3-none-any.whl (570 kB)
#    ---------------------------------------- 0.0/570.5 kB ? eta -:--:--
#    ---------------------------------------- 570.5/570.5 kB 9.7 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp314-cp314-win_amd64.whl (156 kB)
# Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.4-py3-none-any.whl (84 kB)
# Installing collected packages: PyYAML, pyasn1, docutils, rsa, awscli
#
#    ---------------------------------------- 0/5 [PyYAML]
#    ---------------------------------------- 0/5 [PyYAML]
#    ---------------------------------------- 0/5 [PyYAML]
#    -------- ------------------------------- 1/5 [pyasn1]
#    -------- ------------------------------- 1/5 [pyasn1]
#    -------- ------------------------------- 1/5 [pyasn1]
#    -------- ------------------------------- 1/5 [pyasn1]
#    -------- ------------------------------- 1/5 [pyasn1]
#    -------- ------------------------------- 1/5 [pyasn1]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ---------------- ----------------------- 2/5 [docutils]
#    ------------------------ --------------- 3/5 [rsa]
#    ------------------------ --------------- 3/5 [rsa]
#    ------------------------ --------------- 3/5 [rsa]
#    ------------------------ --------------- 3/5 [rsa]
#    ------------------------ --------------- 3/5 [rsa]
#    ------------------------ --------------- 3/5 [rsa]
#    ------------------------ --------------- 3/5 [rsa]
#    ------------------------ --------------- 3/5 [rsa]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    -------------------------------- ------- 4/5 [awscli]
#    ---------------------------------------- 5/5 [awscli]
#
# Successfully installed PyYAML-6.0.3 awscli-1.45.45 docutils-0.19 pyasn1-0.6.4 rsa-4.7.2

# %%
# !pip freeze > requirements.txt
