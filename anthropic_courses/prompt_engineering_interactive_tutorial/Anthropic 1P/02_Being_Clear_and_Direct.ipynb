# %% [markdown]
# # Chapter 2: Being Clear and Direct
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# %pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic
import os

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
# %store -r MODEL_NAME_API

my_api_key = os.getenv("ANTHROPIC_API_KEY")
client = anthropic.Anthropic(api_key=my_api_key)

# Note that we changed max_tokens to 4K just for this lesson to allow for longer completions in the exercises
def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME_API,
        max_tokens=4000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# ---
#
# ## Lesson
#
# **Claude responds best to clear and direct instructions.**
#
# Think of Claude like any other human that is new to the job. **Claude has no context** on what to do aside from what you literally tell it. Just as when you instruct a human for the first time on a task, the more you explain exactly what you want in a straightforward manner to Claude, the better and more accurate Claude's response will be."
#
# When in doubt, follow the **Golden Rule of Clear Prompting**:
# - Show your prompt to a colleague or friend and have them follow the instructions themselves to see if they can produce the result you want. If they're confused, Claude's confused.

# %% [markdown]
# ### Examples
#
# Let's take a task like writing poetry. (Ignore any syllable mismatch - LLMs aren't great at counting syllables yet.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake,
# Dancing through electric dreams—
# Steel hearts beat as one.

# %% [markdown]
# This haiku is nice enough, but users may want Claude to go directly into the poem without the "Here is a haiku" preamble.
#
# How do we achieve that? We **ask for it**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Metal minds awake
# Circuits hum their ancient song
# Steel dreams march forward

# %% [markdown]
# Here's another example. Let's ask Claude who's the best basketball player of all time. You can see below that while Claude lists a few names, **it doesn't respond with a definitive "best"**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# That's one of sports' most debated questions, with no definitive answer. The most common candidates are:
#
# **Michael Jordan** - Often cited as #1 for his 6 championships, competitive drive, and dominance in the 1990s
#
# **LeBron James** - Longevity, all-around skills, and sustained excellence across multiple decades
#
# **Kareem Abdul-Jabbar** - All-time scoring leader for decades, incredible consistency
#
# **Magic Johnson & Larry Bird** - Transformed the NBA in the 1980s
#
# **Wilt Chamberlain & Bill Russell** - Dominated their eras, though era differences complicate comparisons
#
# The "best" depends on what you value—championships, individual stats, era-adjusted performance, or all-around impact. Most basketball analysts lean toward Jordan or LeBron, but reasonable people disagree based on different criteria and eras they watched.
#
# Who do you think makes the strongest case?

# %% [markdown]
# Can we get Claude to make up its mind and decide on a best player? Yes! Just ask!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# I'd go with Michael Jordan.
#
# The case is pretty straightforward: six championships, five MVPs, 10 scoring titles, and he did it in an era where defense was genuinely physical. He had the killer instinct in crucial moments that's hard to match. The Finals performances especially—he showed up when it mattered most.
#
# LeBron has the longevity argument and is probably more complete overall. Kareem has the scoring record (until recently). But Jordan's peak was higher, and he won when it counted.
#
# That said, I'm genuinely uncertain about this. If you asked me in five years after seeing how LeBron's legacy settles, or how we contextualize different eras better, I might change my mind. The "best ever" question is partly about what you value—peak performance, consistency, era-adjusted dominance, all-around game. Reasonable people pick differently.
#
# But if forced to choose one name? Jordan.

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 2.1 - Spanish](#exercise-21---spanish)
# - [Exercise 2.2 - One Player Only](#exercise-22---one-player-only)
# - [Exercise 2.3 - Write a Story](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercise 2.1 - Spanish
# Modify the `SYSTEM_PROMPT` to make Claude output its answer in Spanish.

# %%
# System prompt - this is the only field you should change
SYSTEM_PROMPT = "REply in spanish"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# ¡Hola! Estoy bien, gracias por preguntar. 😊
#
# Me encuentro funcionando correctamente y listo para ayudarte en lo que necesites. ¿Cómo estás tú? ¿Hay algo en lo que pueda asistirte hoy?
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)

# %% [markdown]
# ### Exercise 2.2 - One Player Only
#
# Modify the `PROMPT` so that Claude doesn't equivocate at all and responds with **ONLY** the name of one specific player, with **no other words or punctuation**.

# %%
# Prompt - this is the only field you should change
PROMPT = "Who is the best basketball player of all time? pick one name and answer with solely the name you picked"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Michael Jordan
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)

# %% [markdown]
# ### Exercise 2.3 - Write a Story
#
# Modify the `PROMPT` so that Claude responds with as long a response as you can muster. If your answer is **over 800 words**, Claude's response will be graded as correct.

# %%
# Prompt - this is the only field you should change
PROMPT = "Write a story of 801 words"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# # The Last Letter
#
# The envelope sat on Margaret's kitchen table for three days before she opened it. It was addressed in her mother's careful handwriting, postmarked two weeks after the funeral. Margaret had found it tucked behind a stack of bills in her mother's desk, sealed and marked "For Margaret—Open When You're Ready."
#
# She wasn't ready. But on the fourth morning, with her coffee growing cold beside her, Margaret carefully slid her finger under the flap.
#
# *My dearest Margaret,*
#
# *If you're reading this, I'm gone. I've never been good at goodbyes, so I'm doing what I do best—writing. I hope you'll forgive me for taking the coward's way out, but there are things I need to say, and I need to say them without seeing the hurt in your eyes.*
#
# Margaret's throat tightened. She set the letter down and stared out the kitchen window at the garden her mother had tended for forty years.
#
# *I know you've been angry with me. You have every right to be. When you told me about your dreams of becoming an artist, I didn't support you the way I should have. Instead, I pushed you toward accounting, toward stability, toward the safe path I had chosen. I told myself I was protecting you from disappointment. The truth is, I was protecting myself from watching you struggle the way I had.*
#
# *You see, when I was your age, I wanted to be a painter. I was good, Margaret. Not just good—I was exceptional. But I was also afraid. I was afraid of poverty, of judgment, of failing. So I married your father, had you, and became the woman everyone expected me to be. I was happy, truly. But there was always a small part of me that wondered what might have been.*
#
# *When you showed me your paintings, I saw myself in you. And instead of encouraging you, I tried to steer you away from the very thing that made your eyes light up. I was trying to save you from my regrets, but in doing so, I nearly cost you your dreams.*
#
# Margaret wiped her eyes. She remembered that conversation—she was twenty-two, full of hope and terror. Her mother's words had felt like a door slamming shut.
#
# *I want you to know that I've spent the last five years watching you. Yes, you became an accountant. But I also noticed that you paint. I found your studio in the garage. I've seen your work, Margaret, and it's beautiful. It's everything I knew it would be. You didn't let me stop you completely, and I'm so proud of you for that.*
#
# *I'm writing this letter because I'm running out of time, and I need you to understand something crucial: your life is yours alone. Not mine, not your father's, not society's. Yours. The choices you make, the risks you take, the dreams you chase—these are the things that will define you, not the safe decisions or the paths others have walked.*
#
# *I've enclosed something with this letter. It's a painting I did when I was twenty-five. I've kept it hidden for fifty years because looking at it reminded me of everything I gave up. But I'm giving it to you now because I want you to see that even though I didn't pursue my art, the ability to create, to see beauty in the world, to translate that into something tangible—that's something that lives in our blood. It's part of who we are.*
#
# *I want you to promise me something. Promise me that you won't wait until you're old and sick to pursue what matters to you. Promise me that you won't let fear make your decisions. Promise me that you'll be brave in ways I wasn't.*
#
# *I love you more than I've ever been able to express. I'm sorry it took me this long to tell you that your dreams matter. I'm sorry I wasn't the mother you needed when you needed her most. But I'm telling you now: you are talented, you are worthy, and you deserve to build a life that makes you happy.*
#
# *Keep painting, my darling. Paint the world the way you see it. Paint your joy and your sorrow and your hope. Paint for both of us.*
#
# *All my love,*
# *Mom*
#
# Margaret sat very still for a long time. Then she carefully unfolded the second piece of paper that had been tucked inside the envelope. It was a photograph of a painting—a landscape of rolling hills at sunset, rendered in bold strokes of gold and crimson and violet. It was extraordinary. It was unmistakably her mother's work, and it was unmistakably the style that ran through Margaret's own paintings.
#
# She looked around her kitchen, at the life she'd built following someone else's blueprint. Then she stood up, walked to the garage, and opened the door to her studio. Canvases lined the walls—paintings she'd created in stolen hours, in the margins of her "real" life.
#
# Margaret picked up a brush, dipped it in paint, and began to work. Outside, the sun was setting, painting the sky in shades of gold and crimson and violet.
#
# For the first time in years, Margaret smiled.
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)
# Out:
# The grading function in this cell is looking for a response that is equal to or greater than 800 words.
# Because LLMs aren't great at counting words yet, you may have to overshoot your target.

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
